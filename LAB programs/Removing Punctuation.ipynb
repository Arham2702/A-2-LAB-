# %%
punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
 
inp_str = input("Enter a string: ")
 
spaces = " "
count = 0
no_punc = ""
for char in inp_str:
  if char == spaces:
    count = count + 1
  if char not in punctuations:
       no_punc = no_punc + char

print("Punctuation Free String: ",no_punc)
print("Total number of spaces:", count)

question = input("Do you want to replace any characters in your sentence ?")
if question == "yes":
  remove_char = input("character you want to remove:")
  add_char = input("Character you want to add:")
  print(inp_str.replace(remove_char, add_char))
# Out:
# Enter a string: Arham , hi there.
# Punctuation Free String:  Arham  hi there
# Total number of spaces: 3
# Do you want to replace any characters in your sentence ?yes
# character you want to remove:A
# Character you want to add:a
# arham , hi there.
